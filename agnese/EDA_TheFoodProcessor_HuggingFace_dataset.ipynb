# %% [markdown]
# # The Foodprocessor with new recipes with new features

# %%
# Start the notebook
# !pip install datasets transformers
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (3.0.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.5)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.24.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.16.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)

# %%
from datasets import load_dataset
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')  # To save results
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load dataset
def load_huggingface_dataset(dataset_name, subset=None):
    """
    Load a dataset from Hugging Face and convert to pandas DataFrame

    Args:
        dataset_name (str): Name of the dataset on Hugging Face
        subset (str, optional): Specific subset/configuration of the dataset

    Returns:
        dict: Dictionary of DataFrames for each split (train/test/validation)
    """
    try:
        # Load the dataset
        if subset:
            dataset = load_dataset(dataset_name, subset)
        else:
            dataset = load_dataset(dataset_name)

        # Convert to pandas DataFrames
        dataframes = {}
        for split in dataset.keys():
            dataframes[split] = dataset[split].to_pandas()

        return dataframes

    except Exception as e:
        print(f"Error loading dataset: {str(e)}")
        return None

# Call the function with the correct dataset name
DataFilesPatternsDict = load_huggingface_dataset("Thefoodprocessor/recipe_new_with_features_full")

# %%
# Display the first few rows of the dataset to get an overview
print(dataset['train'].head())
# Out:
#                                      recipe_original  \
# 0  Roasted Carrots and Beets with Pecan Pesto\n1 ...
# 1  Escarole and Olive Salad with Raspberry Dressi...
# 2  Apple Tansie\n12 egg yolks\n6 egg whites\n1/2 ...
# 3  Sauteed Foie Gras with Ginger Poached Pears an...
# 4  Lemon-Scented Broccolini\n1 1/2 pounds broccol...
#
#                                       title_original  \
# 0         Roasted Carrots and Beets with Pecan Pesto
# 1   Escarole and Olive Salad with Raspberry Dressing
# 2                                       Apple Tansie
# 3  Sauteed Foie Gras with Ginger Poached Pears an...
# 4                           Lemon-Scented Broccolini
#
#                                        title_cleaned  \
# 0                Roasted Vegetables with Pecan Pesto
# 1   Escarole and Olive Salad with Raspberry Dressing
# 2                                        Apple Tarts
# 3  Sauteed Foie Gras with Ginger Poached PearsPin...
# 4                                   Lemon Broccolini
#
#                                           recipe_new  \
# 0  Roasted Vegetables with Pecan Pesto\n1 1/2 pou...
# 1  Escarole and Olive Salad with Raspberry Dressi...
# 2  Apple Tarts\n12 egg yolks\n6 egg whites\n1/2 p...
# 3  Sauteed Foie Gras with Ginger Poached PearsPin...
# 4  Lemon Broccolini\n1 1/2 pounds broccolini, was...
#
#                                            wine_type  \
# 0     [Pinot Noir, Beaujolais, Sangiovese, Grenache]
# 1  [Chardonnay, Sauvignon Blanc, Vermentino, Grün...
# 2             [Chardonnay, Riesling, Gewürztraminer]
# 3  [Pinot Noir, Chardonnay, Meursault, Riesling]\n\n
# 4            [Chardonnay, Sauvignon Blanc, Riesling]
#
#                                         allergy_type  \
# 0                         [Nut, Beet, Fruit, Cheese]
# 1                    [Fruit, Vegetable, Nut, Sesame]
# 2                                       [Egg, Fruit]
# 3  [Milk, Nut, Soy, Wheat, Onion, Carrot, Leek, G...
# 4                                            [Lemon]
#
#                                            diet_type         holiday  \
# 0  [(Vegetarian,80),(Gluten-Free,70),(Dairy-Free,...    Thanksgiving
# 1  [(Vegan,80),(Vegetarian,70),(Fruitarian,60),(P...    Thanksgiving
# 2  [(Vegan,0),(Fruitarian,80),(Paleo,70),(LowFODM...    Thanksgiving
# 3  [(Fruitarian,0),(Paleo,0),(Atkins,0),(SouthBea...  New Year's Eve
# 4  [(Vegetarian,80),(Lactovegetarians,70),(Dairy-...          Easter
#
#         cuisine_type                meal_type  \
# 0  American, Italian        Dinner, Side dish
# 1  American, Italian           Salad, Dessert
# 2   French, European           Dessert, Snack
# 3      French, Asian  Dessert, High Tea, Entr
# 4            Italian            Dinner, Salad
#
#                             ingredients_alternatives
# 0  Carrots: sweet potatoes, turnips, rutabaga, ra...
# 1  Raspberries: blueberries, strawberries, blackb...
# 2  Egg yolks: duck eggs, goose eggs, quail eggs\n...
# 3  Duck Foie Gras: Kobe beef, scallops, lobster\n...
# 4  Broccolini: cauliflower, Brussels sprouts, kal...

# %% [markdown]
# ## EDA Plan

# %% [markdown]
# ### 1. Basic Dataset Overview

# %%
# Shape and Info: Get the number of rows and columns, and check the data types for each column to understand the structure.
# Access the 'train' DataFrame
train_df = DataFilesPatternsDict['train']

# Display shape and info of the train DataFrame
print(train_df.shape)
print(train_df.info())
# Out:
# (74465, 11)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74465 entries, 0 to 74464
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   recipe_original           74465 non-null  object
#  1   title_original            74465 non-null  object
#  2   title_cleaned             74465 non-null  object
#  3   recipe_new                74465 non-null  object
#  4   wine_type                 74465 non-null  object
#  5   allergy_type              74465 non-null  object
#  6   diet_type                 74465 non-null  object
#  7   holiday                   74465 non-null  object
#  8   cuisine_type              74465 non-null  object
#  9   meal_type                 74465 non-null  object
#  10  ingredients_alternatives  74465 non-null  object
# dtypes: object(11)
# memory usage: 6.2+ MB
# None

# %%
# Check for Missing Values: Identify if there are any missing values in each column.
# Check for missing values in each column
missing_values = train_df.isnull().sum()
print(missing_values)

# Display columns with missing values only, if any
missing_values = missing_values[missing_values > 0]
print("Columns with missing values:\n", missing_values)
# Out:
# recipe_original             0
# title_original              0
# title_cleaned               0
# recipe_new                  0
# wine_type                   0
# allergy_type                0
# diet_type                   0
# holiday                     0
# cuisine_type                0
# meal_type                   0
# ingredients_alternatives    0
# dtype: int64
# Columns with missing values:
#  Series([], dtype: int64)

# %%
# Check name of columns
# Display column names
print(train_df.columns)
# Out:
# Index(['recipe_original', 'title_original', 'title_cleaned', 'recipe_new',
#        'wine_type', 'allergy_type', 'diet_type', 'holiday', 'cuisine_type',
#        'meal_type', 'ingredients_alternatives'],
#       dtype='object')

# %%
# Check for entire duplicate rows
duplicate_rows = train_df[train_df.duplicated()]
print(f"Number of duplicate rows: {duplicate_rows.shape[0]}")

# Display a few duplicate rows, if any
if not duplicate_rows.empty:
    print(duplicate_rows.head())
# Out:
# Number of duplicate rows: 828
#                                         recipe_original  \
# 1085  Cucumber Salsa\n2 cucumbers, thinly sliced\n3 ...
# 1153  Toasted Baguette\n1 baguette\n1/4 cup olive oi...
# 1198  Banana and Strawberries Delight\n1 1/2 cups gr...
# 1232  Lemon Knots\n12 cups all-purpose flour, plus m...
# 1326  Bread and Butter Pickles\n3 pounds pickling cu...
#
#                        title_original                   title_cleaned  \
# 1085                   Cucumber Salsa                  Cucumber Salsa
# 1153                 Toasted Baguette                Toasted Baguette
# 1198  Banana and Strawberries Delight   Banana and Strawberry Delight
# 1232                      Lemon Knots                     Lemon Knots
# 1326         Bread and Butter Pickles  Bread and Butter Pickle Recipe
#
#                                              recipe_new  \
# 1085  Cucumber Salsa\n2 cucumbers, thinly sliced\n3 ...
# 1153  Toasted Baguette\n1 baguette\n1/4 cup olive oi...
# 1198  Banana and Strawberry Delight\n1 1/2 cups gran...
# 1232  Lemon Knots\n12 cups all-purpose flour, plus m...
# 1326  Bread and Butter Pickle Recipe\n3 pounds pickl...
#
#                                               wine_type  \
# 1085           [Riesling, Gewürztraminer, Pinot Grigio]
# 1153        [Chardonnay, Sauvignon Blanc, Pinot Grigio]
# 1198  [Chardonnay, Sauvignon Blanc, Riesling, Moscat...
# 1232   [Chardonnay, Sauvignon Blanc, Riesling, Moscato]
# 1326  [Chardonnay, Riesling, Sauvignon Blanc, Vermen...
#
#                             allergy_type  \
# 1085    [Cow's milk, Soy, Allium, Spicy]
# 1153                             [Wheat]
# 1198                 [Dairy, Egg, Fruit]
# 1232                         [Milk, Egg]
# 1326  [Cucumber, Mustard, Pepper, Sugar]
#
#                                               diet_type       holiday  \
# 1085  [(Vegetarian,80),(Dairy-Free,70),(Lactovegetar...   4th of July
# 1153  [(Paleo,80),(Atkins,70),(SouthBeach,60),(LowFO...  Thanksgiving
# 1198  [(Vegan,0),(Vegetarian,0),(Dairy-Free,80),(Fru...        Summer
# 1232  [(Vegetarian,80),(Dairy-Free,70),(Lactovegetar...        Easter
# 1326  [(Vegetarian,80),(Gluten-Free,70),(Dairy-Free,...  Thanksgiving
#
#           cuisine_type                   meal_type  \
# 1085             Asian            Appetizer, Snack
# 1153            French  Breakfast, Brunch, Dessert
# 1198  American, French          Breakfast, Dessert
# 1232          American  Breakfast, Brunch, Dessert
# 1326          American           Dinner, Appetizer
#
#                                ingredients_alternatives
# 1085  Cucumbers: bell peppers, zucchini, eggplant\nS...
# 1153  Baguette: ciabatta, focaccia, sourdough bread\...
# 1198  Sugar: brown sugar, honey, maple syrup\nButter...
# 1232  Flour: whole wheat flour, pastry flour, almond...
# 1326  Cucumbers: bell peppers, jalapenos, cauliflowe...

# %% [markdown]
# It seems title_original and title_cleaned are identical.
# Check for whether could indeed explain why certain rows appear as duplicates.

# %%
# Count rows where title_original and title_cleaned are the same
identical_titles_count = (train_df['title_original'] == train_df['title_cleaned']).sum()
print(f"Number of rows where title_original and title_cleaned are identical: {identical_titles_count}")
# Out:
# Number of rows where title_original and title_cleaned are identical: 17371

# %% [markdown]
# ### 2. Textual Column Analysis

# %%
# Display a few samples from the textual columns
print(train_df[['recipe_original', 'title_original', 'title_cleaned', 'recipe_new']].sample(5))
# Out:
#                                          recipe_original  \
# 18982  Whiskey Tri-Tip\n2 1/2 pounds tri-tip steak\n2...
# 58033  Herb Stuffed Tomatoes\n5 beefsteak tomatoes\n1...
# 62901  Cast-Iron Pizza\n1 pound frozen store-bought p...
# 13165  Double-Yummy Chili Stuffed Baked Potatoes\n6 l...
# 58403  Meatless Shepherd's Pie with Horseradish-Chedd...
#
#                                           title_original  \
# 18982                                    Whiskey Tri-Tip
# 58033                              Herb Stuffed Tomatoes
# 62901                                    Cast-Iron Pizza
# 13165          Double-Yummy Chili Stuffed Baked Potatoes
# 58403  Meatless Shepherd's Pie with Horseradish-Chedd...
#
#                                            title_cleaned  \
# 18982                                    Whiskey Tri-Tip
# 58033                        Stuffed Tomatoes with Herbs
# 62901                                 Pizza in cast iron
# 13165                       Chili Stuffed Baked Potatoes
# 58403  Meatless Shepherd's Pie with Potatoes and Hors...
#
#                                               recipe_new
# 18982  Whiskey Tri-Tip\n2 1/2 pounds tri-tip steak\n2...
# 58033  Stuffed Tomatoes with Herbs\n5 beefsteak tomat...
# 62901  Pizza in cast iron\n1 pound frozen store-bough...
# 13165  Chili Stuffed Baked Potatoes\n6 large russet p...
# 58403  Meatless Shepherd's Pie with Potatoes and Hors...

# %%
# Display a random sample of 5 rows from all columns
train_df.sample(5)
# Out:
#                                          recipe_original  \
# 72683  Brown Butter Risotto with Lobster\n1 pound (ab...
# 58835  Hot Cocoa Smoothie\n3/4 cup chocolate oat milk...
# 30473  Green Tomato Pie Turnovers\n5 green tomatoes\n...
# 44744  Wild Rocket and Chilli Spaghetti\n1 pound 1-ou...
# 5964   Maple-Roasted Bacon\n3/4 pound thick-cut smoke...
#
#                           title_original  \
# 72683  Brown Butter Risotto with Lobster
# 58835                 Hot Cocoa Smoothie
# 30473         Green Tomato Pie Turnovers
# 44744   Wild Rocket and Chilli Spaghetti
# 5964                 Maple-Roasted Bacon
#
#                               title_cleaned  \
# 72683     Brown Butter Risotto with Lobster
# 58835                Hot Chocolate Smoothie
# 30473            Green Tomato Pie Turnovers
# 44744  Spaghetti with Wild Rocket and Chili
# 5964                    Maple Roasted Bacon
#
#                                               recipe_new  \
# 72683  Brown Butter Risotto with Lobster\n1 pound (ab...
# 58835  Hot Chocolate Smoothie\n3/4 cup chocolate oat ...
# 30473  Green Tomato Pie Turnovers\n5 green tomatoes\n...
# 44744  Spaghetti with Wild Rocket and Chili\n1 pound ...
# 5964   Maple Roasted Bacon\n3/4 pound thick-cut smoke...
#
#                                                wine_type  \
# 72683  [Chardonnay, Pinot Grigio, Sauvignon Blanc, Sp...
# 58835    [Merlot, Cabernet Sauvignon, Malbec, Zinfandel]
# 30473  [Chardonnay, Sauvignon Blanc, Riesling, Pinot ...
# 44744          [Barolo, Barbaresco, Dolcetto, Aglianico]
# 5964                      [Burgundy, Merlot, Pinot Gris]
#
#                           allergy_type  \
# 72683         [Fish, Rice, Dairy, Nut]
# 58835                      [Milk, Nut]
# 30473                [Nut, Dairy, Egg]
# 44744  [Milk, Anchovy, Citrus, Gluten]
# 5964                     [Meat, Sugar]
#
#                                                diet_type          holiday  \
# 72683  [(Vegetarian,80),(Dairy-Free,70),(Lactovegetar...     Thanksgiving
# 58835  [(Vegan,90),(Dairy-Free,80),(Lactovegetarians,...  Winter Solstice
# 30473  [(Vegan,80),(Vegetarian,70),(Dairy-Free,60),(F...     Thanksgiving
# 44744  [(Vegetarian,80),(Gluten-Free,70),(Dairy-Free,...   New Year's Eve
# 5964   [(Paleo,80),(Ketogenic,70),(Atkins,60),(SouthB...     Thanksgiving
#
#              cuisine_type                   meal_type  \
# 72683   American, Italian              Dinner, Entree
# 58835  American, European          Breakfast, Dessert
# 30473            American           Dinner, Appetizer
# 44744             Italian              Dinner, Entree
# 5964             American  Breakfast, Brunch, Dessert
#
#                                 ingredients_alternatives
# 72683  Frozen lobster tails: fresh lobster tails, shr...
# 58835  Chocolate oat milk: almond milk, soy milk, coc...
# 30473  Green tomatoes: yellow tomatoes, cherry tomato...
# 44744  Dried spaghetti: bucatini, linguine, fettuccin...
# 5964   Bacon: Canadian bacon, prosciutto, serrano ham...

# %% [markdown]
# ### 3. Categorical Data Analysis

# %%
# Columns like wine_type, allergy_type, diet)type, holiday, cuisine_tyep, and meal_type are categorical.
# Unique values and counts: for each categorical column, list teh unique values and counts to understand variety and ferquency of categories.

# List unique values and their counts for each categorical column
categorical_columns = ['wine_type', 'allergy_type', 'diet_type', 'holiday', 'cuisine_type', 'meal_type']

for column in categorical_columns:
    print(f"\nUnique values and counts for '{column}':")
    print(train_df[column].value_counts())
# Out:
# Unique values and counts for 'wine_type':
# wine_type
# [Chardonnay, Sauvignon Blanc, Riesling, Pinot Grigio]            6708
# [Chardonnay, Pinot Grigio, Sauvignon Blanc, Riesling]            4051
# [Chardonnay, Sauvignon Blanc, Pinot Grigio, Riesling]            1921
# [Chardonnay, Riesling, Gewürztraminer, Pinot Grigio]             1750
# [Chardonnay, Sauvignon Blanc, Pinot Grigio, Vermentino]          1699
#                                                                  ...
# [Rum, Bourbon, Brandy]                                              1
# [Tequila, Moscato, Sauvignon Blanc, Pinot Grigio]                   1
# [Lapsang Souchong, Chardonnay, Sauvignon Blanc, Pinot Grigio]       1
# [Marsanne, Bois du Renard, Languedoc]\n\n                           1
# [Chardonnay, Pinotage, Zinfandel]                                   1
# Name: count, Length: 5871, dtype: int64
#
# Unique values and counts for 'allergy_type':
# allergy_type
# [Alcohol]                              555
# [Dairy, Sugar]                         436
# [Dairy, Fruit]                         427
# [Dairy, Egg]                           408
# [Milk, Egg]                            400
#                                       ...
# [Nut, Dairy, Grain, Meat]                1
# [Coconut, Eggs, Sugar]                   1
# [Milk, Egg, Allium, Cheese, Grain]       1
# [Cabbage, Butter]                        1
# [Cow's milk, Gluten, Garlic, Lemon]      1
# Name: count, Length: 31229, dtype: int64
#
# Unique values and counts for 'diet_type':
# diet_type
# [(Paleo,80),(Ketogenic,70),(Atkins,60),(SouthBeach,50)]                                                                                                                                                           3893
# [(Vegetarian,80),(Dairy-Free,70),(Lactovegetarians,60),(OvoVegetarian,50),(Paleo,40)]                                                                                                                             3637
# [(Paleo,80),(Ketogenic,70),(Atkins,60),(LowFODMAP,50)]                                                                                                                                                            2215
# [(Paleo,80),(Atkins,70),(SouthBeach,60),(LowFODMAP,50)]                                                                                                                                                           2072
# [(Paleo,80),(Ketogenic,70),(Atkins,60),(SouthBeach,50),(LowFODMAP,40)]                                                                                                                                            1414
#                                                                                                                                                                                                                   ...
# [(Vegetarian,90),(Lactovegetarians,80),(Dairy-Free,70),(OvoVegetarian,60)].\nNote:Pignolimeans"pinenut"inItalian.\n\ntitle:\nRoastedCarrots.\ningredients:\n4largecarrots,peeled\n2tbspoliveoil\n1tsphoney\n1        1
# [(Dairy-Free,80),(Gluten-Free,70),(Vegetarian,60),(Paleo,40)].\n\nNote:*denotesanoptionalingredient                                                                                                                  1
# [(Vegan,0),(Fruitarian,0),(Pescatarian,70),(Pollotarian,60),(LowFODMAP,50)]                                                                                                                                          1
# [(Vegetarian,80),(Dairy-Free,70),(Gluten-Free,60),(Paleo,50)].\n\ntitle:\nBakedSalmonwithLemon-HerbButter.\ningredients:\nSalmonfillet(6oz)\n1/4cupunsaltedbutter,softened\n2tbspfreshparsley,chopped\n2             1
# [(Paleo,80),(LowFODMAP,70),(Gluten-Free,60),(Vegetarian,50),(Fruitarian,40)].\n\ntitle:\nBakedChickenThighswithHerbs.\ningredients:\n4boneless,skinlesschickenthighs\n1/4cupoliveoil\n2tbspchoppedfreshrosemar       1
# Name: count, Length: 9300, dtype: int64
#
# Unique values and counts for 'holiday':
# holiday
# Thanksgiving                                      30103
# Easter                                            12535
# New Year's Eve                                     9417
# 4th of July                                        3824
# Halloween                                          3520
#                                                   ...
# Fundraiser                                            1
# Mai Tai Tuesday (a made-                              1
# Tết (Vietnamese New Year)                             1
# Chirstmas                                             1
# German Christmas MarketPlease answer with only        1
# Name: count, Length: 271, dtype: int64
#
# Unique values and counts for 'cuisine_type':
# cuisine_type
# American                           19038
# Italian                             6659
# American, Italian                   5802
# American, French                    5143
# American, Mexican                   4188
#                                    ...
# American, Thai, Vietnamese             1
# Indian, Southern Indian                1
# Russian, Japanese                      1
# French, Bread                          1
# American, Mexican, Southwestern        1
# Name: count, Length: 1385, dtype: int64
#
# Unique values and counts for 'meal_type':
# meal_type
# Dinner, Appetizer               8398
# Dinner, Entree                  7542
# Dessert, Snack                  6581
# Dessert, High Tea               5840
# Dinner, Lunch                   4568
#                                 ...
# Drinks, High Tea, Picnic           1
# Dinner, Holiday, Main Course       1
# Appetizer                          1
# Drinks, Appetizer, Dessert         1
# Lunch, SnackPlease provide         1
# Name: count, Length: 548, dtype: int64

# %%
# List unique values for each categorical column
categorical_columns = ['wine_type', 'allergy_type', 'diet_type', 'holiday', 'cuisine_type', 'meal_type']

for column in categorical_columns:
    print(f"\nUnique values for '{column}':")
    print(train_df[column].unique())
# Out:
# Unique values for 'wine_type':
# ['[Pinot Noir, Beaujolais, Sangiovese, Grenache]'
#  '[Chardonnay, Sauvignon Blanc, Vermentino, Grüner Veltliner]'
#  '[Chardonnay, Riesling, Gewürztraminer]' ...
#  '[Chardonnay, Riesling, Gouda Cheese, Tempranillo]'
#  '[Pinot Grigio, Chianti, Riesling, Sparkling Shiraz]'
#  '[Chardonnay, Pinotage, Zinfandel]']
#
# Unique values for 'allergy_type':
# ['[Nut, Beet, Fruit, Cheese]' '[Fruit, Vegetable, Nut, Sesame]'
#  '[Egg, Fruit]' ...
#  "[Cow's milk, Eggs, Garlic, Onion, Rice, Spinach, Wheat]"
#  '[Fish, Beans, Herbs, Dairy]' "[Cow's milk, Gluten, Garlic, Lemon]"]
#
# Unique values for 'diet_type':
# ['[(Vegetarian,80),(Gluten-Free,70),(Dairy-Free,60),(Paleo,50),(Lactovegetarians,40)]'
#  '[(Vegan,80),(Vegetarian,70),(Fruitarian,60),(Paleo,50),(LowFODMAP,40)]'
#  '[(Vegan,0),(Fruitarian,80),(Paleo,70),(LowFODMAP,60),(Vegetarian,50)]'
#  ...
#  '[(Paleo,90),(LowFODMAP,80),(Gluten-Free,70),(Dairy-Free,60),(Vegetarian,50),(OvoVegetarian,40)]'
#  '[(Paleo,80),(Ketogenic,70),(Atkins,60),(LowFODMAP,50)].\n\ntitle:\nRoastedCarrots.\ningredients:\n11/2pounds(680grams)carrots,peeledandcutinto1/4-inchthickslices\n1/4cup(60ml)oliveoil'
#  '[(Paleo,80),(LowFODMAP,70),(Gluten-Free,60),(Vegetarian,50),(Fruitarian,40)].\n\ntitle:\nBakedChickenThighswithHerbs.\ningredients:\n4boneless,skinlesschickenthighs\n1/4cupoliveoil\n2tbspchoppedfreshrosemar']
#
# Unique values for 'holiday':
# ['Thanksgiving' "New Year's Eve" 'Easter' 'Hanukkah' 'Diwali'
#  'Winter/Holiday Season' '4th of July' 'Summer BBQ' 'Eid al-Adha'
#  'Holiday Season' "New Year's Day" 'Halloween' 'Independence Day'
#  'Labor Day' 'Summer' 'Winter Solstice' 'Mardi Gras' 'Birthdays'
#  'Fourth of July' 'Super Bowl' 'Mexican Independence Day'
#  "Italian New Year's Eve" 'Korean New Year (Seollal)' 'Day of the Dead'
#  'Holi' 'Winter Holidays' 'Jamaican Independence Day' 'Lunar New Year'
#  'Winter BreakPlease answer with only one' 'Chinese New Year'
#  'Summer picnic' 'Passover' 'Hispanic Heritage Month'
#  'Winter Breakrecipe title: ' 'Caribbean Carnival'
#  "New Year'srecipe title:" 'Holiday Party' 'Christmas' "St Patrick's Day"
#  'None (this is not a holiday dish'
#  'SummerPlease answer with only one phrase' 'Eid al-Fitr' 'Summer/Beach'
#  'Hawaiian New Year' 'Greek Easter' 'Ramadan'
#  "Hawaiian New Year (New Year'" 'Wedding' 'Grill-a-Palooza'
#  'Italian Christmas' 'Indian Festival of Lights (Diwali' 'Memorial Day'
#  "Dutch New Year's Eve (S" 'Wedding/Honeymoon' "Valentine's Day"
#  'Thailand New Year (Songkran)'
#  'Italian ChristmasPlease answer with only one' 'Birthday'
#  'Italian Heritage Night' 'Kwanzaa' 'Margarita Day (February ' 'Spring'
#  'None' "Mother's Day" 'Fat Tuesday' 'Winter Break' "Father's Day"
#  'Winter/Hanukkah' 'Eid-al-Fitr' 'Mint Julep Day (April ' 'Groundhog Day'
#  'Holiday Cooking with Kids' 'Italian-American Heritage Month'
#  'Caribbean Christmas' 'Cuban Independence Day' 'Italian Christmas Dinner'
#  'ChocolatePlease answer with only one' 'Persian New Year (Nowruz)'
#  'FiestasPlease answer with only one' 'Summer Camp'
#  'None (this dish is not associated with any' 'Midsummer'
#  'Summer Camping Trip' 'Holiday (no specific holiday)' 'Super Bowl Sunday'
#  'May Day' 'Ethiopian New Year' 'Epiphany'
#  'Holiday of Lights (Chinese New' 'Lent' 'Springrecipe title: S'
#  'Thai New Year (Songkran)' 'Margarita Monday (a made-up'
#  'Winter Solstice/ Christmas' 'Oscar Night' 'New Year'
#  'SpringPlease answer with only one phrase for'
#  'Holiday of lights (Diwali)' "New Year'sPlease answer with only"
#  'Japanese New Year (Oshogats' 'Dia de los Muertos (Day of'
#  'Holidays (general)' 'Winter WonderlandPlease answer with only'
#  'Latin American Fiesta' 'Winter Wonderland' 'Winter/Spring Break'
#  'HawaiiPlease answer with only' 'Winter Weddings' "New Year's"
#  'Italian Heritage Month' 'Caribbean Independence Day'
#  'Vietnamese New Year (Tết)' 'Ethiopian New Year (Enkut' 'Australia Day'
#  'Chocolate Lovers Day' 'Korean Thanksgiving' 'Nigerian Independence Day'
#  'Winter Holidays (eg' 'Oktoberfest' 'Vietnamese New Year' 'Nowruz'
#  'Italian-American Cuisine (e' 'Grill-Out' 'Summer Cookout'
#  'Holiday Cookies' 'Vietnamese New Year (Tet)'
#  'Middle Eastern New Year (Ramadan)' 'Mexican Holidays (eg'
#  'None (not associated with any specific holiday)'
#  'WinterPlease answer with only one phrase'
#  "Italian New Year (La Festa dell'" 'Indian New Year (Makar Sankr'
#  'Girl Scout Cookies' 'Tet (Vietnamese New Year)'
#  'Italian-American Celebration (e'
#  'ChristmasPlease answer with only one phrase'
#  'Día de los Muertos (Day of' 'Superbowl' 'Mint Julep Festival'
#  'German Christmas Markets' 'Holiday (not specific to any particular hol'
#  'WeddingPlease answer with only one' "New Year's Resolution"
#  'Hawaiian New Year (Makah' 'Fair/Carnival' 'Winterrecipe title: '
#  'All Hallows Eve' 'Holiday of Lights (Diwali' 'Holy Week (Easter)'
#  'Holy Week/Easter' 'Passover/Easter' 'Holiday of lights (eg'
#  'Día de los Muertos' 'Fiesta' 'Holiday of Lights (Hanuk'
#  'Belgian Independence Day' "Winter/New Year's Eve"
#  'Holiday Season (eg Christmas' 'Olympics' 'Friday'
#  'Hindu New Year (Nyepi)' 'Fairs/Carnivals' 'Senegalese Independence Day'
#  'Carnival' 'Fundraiser for School' 'Chirstmas' 'July 4th'
#  'Tết (Vietnamese New Year)' 'Margarita Monday' 'Hawaiian Luau'
#  'Chilean New Year (Año Nuevo' 'French Bakery Day' 'Christmas Eve'
#  'Winter Breakfast' 'Summer Solstice' 'Mai Tai Tuesday (a made-'
#  'Fundraiser' 'Holiday Cookie ExchangePlease answer' 'Winter Olympics'
#  'Girl Scout Cookie Sale' 'Día de Muertos (Day of the'
#  'Holiday of Spain (eg' ' Cinco de Mayo' 'Summer/Fourth of July' 'Hawaii'
#  'Vegetarian Thanksgiving' 'Spring/Easter' 'Holiday Breakfast'
#  'LentPlease answer with only one phrase'
#  'MauiPlease answer with only one' 'Canada Day' 'Low Carb Diet'
#  'Grill-out' 'Grilled Cheese Day (April Fool' 'Summer BBQs'
#  'None (no specific holiday)' 'Weddings' 'Earth Day'
#  'Hawaii Five-O (New Year' 'Jamaica Independence Day'
#  'Indian New Year (Diwali)' 'Latin American Independence Day'
#  'Holiday (winter)' 'Holiday of Lights (eg' 'Weddings/Anniversaries'
#  'Grilled Cheese Day' 'HolidayPlease answer with only one' 'Thai New Year'
#  "St Joseph's Day" 'Holiday (General)' 'Deepavali'
#  'Winter Break/Holiday Season' 'Italian Heritage Festival'
#  'Grill-A-Palooza' 'Holiday Brunch' 'Holiday BreakPlease answer with only'
#  'Thansgiving' 'Summer/4th of July' 'Hawaii (Thanksgiving)'
#  'Winter Celebration (eg' "Hungarian New Year's Eve"
#  'Holiday of Eid al-Adha' 'South African Independence Day'
#  'Filipino New Year (Ati-ati' 'Italian-American Holiday Feasts'
#  'Pancake Day/Shrove Tues' 'Holiday (eg Eid' 'Dia de los Muertos'
#  "Italian New Year's Eve (Cap" 'Holiday of lights (Hanukk'
#  'Spring Equinox' 'Fall/Thanksgiving' 'Graduation Party' 'Pancake Day'
#  'Holiday (Indian festival)' 'Iranian New Year (Nowruz)' 'Jul 4th'
#  'Latin American Holidays (eg' 'Margarita MondayPlease answer with'
#  'Malaysian New Year (Hari Raya' "French New Year's Eve" 'Tuesday'
#  'Indian Festival of Colors (Holi)' 'Monday' 'Hiking Season'
#  'May Day/Labor Day' 'Summer/Carnival'
#  'None (not associated with any particular holiday)' 'Shower'
#  'Sunday Brunch' 'Oscars' 'Puerto Rican Day' 'Circus-themed party'
#  'Winter' 'French National Day (July 14' "French New Year (New Year's E"
#  'Italian Christmas Feast' 'Indian Independence Day' 'Anniversary'
#  'Holiday (eg New Year' 'Holiday (eg Hanuk' 'Derby Day' 'Rosh Hashanah'
#  'Hawaiian luau' 'Back to School' 'Partyrecipe title: '
#  'Spanish ChristmasPlease answer with only one'
#  'Italian-American Celebration' 'Jazz Festival' "New Year's Day (Brazil)"
#  'German Christmas MarketPlease answer with only']
#
# Unique values for 'cuisine_type':
# ['American, Italian' 'French, European' 'French, Asian' ...
#  'American, British, French, Italian' 'MediterraneanText: Sp'
#  'American, Mexican, Southwestern']
#
# Unique values for 'meal_type':
# ['Dinner, Side dish' 'Salad, Dessert' 'Dessert, Snack'
#  'Dessert, High Tea, Entr' 'Dinner, Salad' 'Dessert, High Tea'
#  'Dessert, Appetizer' 'Dinner, Entree' 'Dinner, Lunch, Snack'
#  'Lunch, Appetizer' 'Dessert, Soup' 'Dinner, Entrée' 'Dinner, Appetizer'
#  'Breakfast, Brunch, Dinner' 'Dinner, Lunch' 'Dinner, Soup'
#  'Breakfast, Dessert' 'Lunch, Snack' 'Dinner, Lunch, Appetizer'
#  'Appetizer, Drinks' 'Breakfast, Brunch' 'Dinner, Entree, High Tea'
#  'Appetizer, Dinner' 'Dinner, Lunch, Soup' 'Breakfast, Brunch, Dessert'
#  'High Tea, Brunch' 'Dinner, Picnic' 'Salad, Lunch, Snack' 'Salad, Dinner'
#  'Dessert, Drinks' 'Appetizer, Drink' 'Soup, Dinner' 'Breakfast, Lunch'
#  'Dinner, Snack' 'Dessert, Picnic' 'Appetizer, DinnerPlease'
#  'Dinner, AppetizerPlease' 'Dinner, Lunch, Salad' 'Salad, Lunch'
#  'Breakfast, Lunch, Dinner' 'Appetizer, Snack' 'Breakfast, High Tea, Dess'
#  'Entree, Appetizer' 'Appetizer, SnackPlease' 'Dinner, High Tea, Picnic'
#  'Drinks, Appetizer' 'Lunch, Dinner' 'Dessert, Drink' 'Dessert, Salad'
#  'Dessert, Breakfast' 'Brunch, Dinner, Snack' 'Dessert, Birthday'
#  'Dinner, Appetizer, Soup' 'Entree, Dinner' 'Breakfast, Brunch, Appetizer'
#  'Drink, Soup' 'Dinner, Entree, Salad' 'Dinner, Appetizer, Side dish'
#  'Drink, Brunch' 'Dessert, Brunch' 'Appetizer, High Tea' 'Brunch, Dessert'
#  'Breakfast, Brunch, Snack' 'Lunch, Dinner, Side dish'
#  'Soup, Lunch, Dinner' 'Breakfast, Dinner' 'Appetizer, Dessert'
#  'Dinner, Brunch' 'Breakfast, Dinner, Entrée' 'Breakfast, Snack'
#  'Salad, Appetizer' 'Entrée, Dinner' 'Drinks, High Tea'
#  'Dinner, Appetizer, Entree' 'Lunch, Dinner, Appetizer'
#  'Appetizer, BrunchPlease' 'Dessert, Tea' 'Dinner, Appetizer, High Tea'
#  'Dinner, Holiday, Side dish' 'Lunch, Dinner, Snack' 'Lunch, Salad'
#  'Salad, Lunch, Dinner' 'Dinner, Appetizer, Salad' 'Dressing, Salad'
#  'Dessert, Lunch, Snack' 'Salad, Side dish' 'Breakfast, Tea'
#  'Appetizer, Brunch, Dessert' 'Breakfast, Brunch, Lunch'
#  'Dinner, Breakfast' 'Dinner, Picnic, Salad' 'Dessert, Holiday'
#  'Dinner, Lunch, Entree' 'Brunch, Lunch, Dessert'
#  'Appetizer, Brunch, Dinner' 'Dinner, Lunch, Entrée'
#  'Appetizer, Lunch, Dinner' 'Dinner, High Tea' 'Soup, Salad' 'Dessert'
#  'Dessert, Lunch' 'Appetizer, Dinner, Soup' 'Lunch, Dinner, Salad'
#  'Breakfast, Lunch, Dessert' 'Breakfast, Dinner, Snack'
#  'Breakfast, Dinner, Appetizer' 'High Tea, Snack' 'Soup, Appetizer'
#  'Appetizer, Salad' 'Dessert, Dinner' 'Salad, Snack' 'Dessert, Beverage'
#  'Dinner, Lunch, Side dish' 'Dinner, Entree, Lunch'
#  'Dinner, Entree, Picnic' 'Side dish, Salad' 'Appetizer, High Tea, Dess'
#  'Appetizer, Dinner, Entree' 'Soup' 'Entree, Dessert'
#  'Salad, Lunch, Dessert' 'Appetizer, Dinner, Snack'
#  'Dinner, Lunch, Picnic' 'Dinner, Appetizer, Picnic'
#  'Dinner, Lunch, High Tea' 'Snack, Appetizer' 'Dinner, Appetizer, Drinks'
#  'Dinner, LunchPlease provide' 'Drink, Dessert' 'Dinner, Appetizer, Snack'
#  'Entree, Lunch' 'Middle Eastern, Dinner, Appetizer'
#  'Appetizer, High Tea, Picnic' 'Entrée, Appetizer' 'High Tea, Lunch'
#  'Lunch, SaladPlease provide' 'Breakfast, Appetizer, Dess'
#  'Dessert, Lunch, Salad' 'Beverage, High Tea' 'Appetizer, Lunch'
#  'Dinner, Entree, Side dish' 'Entree, Soup' 'Dinner, SnackPlease provide'
#  'Dessert, Thanksgiving' 'Lunch, Picnic' 'Dessert, High Tea, Picnic'
#  'Entrée, Lunch' 'Dinner, Picnic, Dessert' 'Dessert, Middle EasternPlease'
#  'Dinner, High Tea, Soup' 'Appetizer, DrinksPlease'
#  'Appetizer, Lunch, Dessert' 'Appetizer, Dinner, High Tea'
#  'Drink, High Tea' 'Drink, Snack' 'Drink, Appetizer'
#  'Dinner, Appetizer, Dessert' 'Appetizer, Salad, Dessert'
#  'Dinner, Holiday' 'Breakfast, Appetizer, Snack'
#  'Dessert, ItalianPlease let' 'Dinner, Entree, Vegan' 'Entree, Asian'
#  'Dinner, Lunch, Breakfast' 'Dinner, Seafood' 'Appetizer, Snack, Dinner'
#  'Soup, Lunch' 'Dinner, Latin American' 'Dinner, PicnicPlease provide'
#  'Lunch, Dessert' 'Dessert, Halloween' 'Appetizer, Picnic'
#  'Dinner, High Tea, Salad' 'Drink, Brunch, Appetizer'
#  'Appetizer, Asian, Dinner' 'Drinks, Party' 'Pasta, Dinner, Appetizer'
#  'Appetizer, LunchPlease' 'Drinks, Dinner' 'Breakfast, Lunch, Soup'
#  'Drinks, Dessert' 'Appetizer, Dinner, Drinks' 'Soup, Snack'
#  'High Tea, Dessert' 'Appetizer, Dinner, Picnic'
#  'Dinner, Salad, Appetizer' 'Dessert, Appetizer, High Te'
#  'Dinner, Appetizer, Entrée' 'Entree, Picnic' 'Breakfast, High Tea'
#  'Appetizer, Dinner, Salad' 'Brunch, Appetizer'
#  'Dessert, Drink, Appetizer' 'Dessert, Brunch, Appetizer'
#  'Side dish, Appetizer' 'Salad, Soup' 'Dinner, ItalianPlease let me'
#  'Dressing, Sandwich' 'Coffee, Drink, Dessert' 'Side dish, Snack'
#  'Breakfast, Lunch, Salad' 'Dessert, Holiday, Salad' 'Breakfast'
#  'Dinner, Drinks' 'Appetizer, SaladPlease' 'Breakfast, Lunch, Snack'
#  'Appetizer, Brunch' 'Salad, Dressing' 'Drink, High Tea, Picnic'
#  'Lunch, Picnic, Snack' 'Breakfast, Soup' 'No meal type' 'Soup, Dessert'
#  'Dessert, Birthday Party' 'Drinks, Brunch' 'Lunch, Appetizer, Dessert'
#  'Pasta, Dinner' 'Entrée, Pasta' 'Lunch, Dinner, Sandwich'
#  'Lunch, Appetizer, Salad' 'Dessert, High Tea, Snack'
#  'Dinner, Side dishPlease' 'Appetizer, Tapas' 'Breakfast, Coffee'
#  'Dessert, Latin AmericanPlease' 'Snack, Dessert'
#  'Appetizer, Drink, High Tea' 'Dinner, KoreanPlease provide the'
#  'Dinner, High TeaPlease' 'Breakfast, Dinner, Soup'
#  'Dinner, Appetizer, Brunch' 'Breakfast, Appetizer, Dinner'
#  'Breakfast, DinnerPlease' 'Dinner, Lunch, Rice'
#  'Dinner, Family MealPlease' 'Appetizer, Soup' 'Dinner, LunchPlease let'
#  'Dinner, Lunch, Sandwich' 'Dinner, Breakfast, Appetizer'
#  'Dinner, Holiday Meals' 'Middle Eastern, Appetizer, Dinner'
#  'Dinner, SaladPlease let' 'Tea, High Tea' 'Brunch, Lunch, Dinner'
#  'Lunch, High Tea' 'Dinner, JapanesePlease let me'
#  'Appetizer, Dinner, Lunch' 'Salad, Lunch, Appetizer'
#  'Dessert, Breakfast, Snack' 'Dessert, KoreanPlease let'
#  'Breakfast, Lunch, Appetizer' 'Dinner, Middle EasternPlease let'
#  'Cocktail, Appetizer' 'Beverage, Dessert' 'Tea, Snack'
#  'Lunch, Appetizer, Snack' 'Appetizer, Middle Eastern, Dinner'
#  'Appetizer, Brunch, Snack' 'Entree, High Tea' 'High Tea, Picnic'
#  'Lunch, Breakfast' 'Entree, High Tea, Picnic' 'Breakfast, Salad'
#  'Dinner, Breakfast, Snack' 'Dinner, Soup, Appetizer'
#  'Dinner, Lunch, Sauce' 'Cocktail, Dessert' 'Snack, High Tea'
#  'Dinner, Middle Eastern, Entree' 'Appetizer, Dinner, Wine'
#  'Appetizer, Lunch, Snack' 'Dinner, Entree, Wine pairing'
#  'Side dish, Dinner' 'Appetizer, Salad, Entrée' 'Dessert, BBQ, Picnic'
#  'Picnic, Lunch' 'Dessert, FrenchPlease let' 'Dinner, Brunch, Appetizer'
#  'Appetizer, Dinner, Party' 'Appetizer, Holiday, Salad'
#  'Dessert, BreakfastPlease' 'Lunch, Appetizer, Dinner'
#  'Dinner, RussianPlease let me' 'Dinner, BBQ' 'Dinner, Roast'
#  'Picnic, Dinner' 'Dinner, Italian' 'Entree, High Tea, Dinner'
#  'Brunch, High Tea' 'Dinner, Fish, Entree' 'Brunch, Lunch, Appetizer'
#  'Dessert, Lunch, Soup' 'Entree, Lunch, Dinner'
#  'Dinner, Entree, Vegetarian' 'Dessert, Entrée' 'Salad, Picnic'
#  'Dessert, Breakfast, Brunch' 'Breakfast, Beverage' 'Dinner, Grill'
#  'Appetizer, Dinner, Middle Eastern' 'Dessert, Coffee Break'
#  'Dinner, PizzaPlease provide' 'Lunch, Brunch, Appetizer'
#  'Dinner, Holiday, Entree' 'Salad' 'Entree, Vietnamese'
#  'Dinner, GreekPlease let me' 'Appetizer, Holiday'
#  'Dessert, Appetizer, Snack' 'Tea, Dessert' 'Dessert, High Tea, Soup'
#  'Dinner, SoupPlease provide' 'Beverage, Snack'
#  'Appetizer, High Tea, Snack' 'Appetizer, Salad, Dinner'
#  'Dessert, High Tea, Appet' 'Dinner, SeafoodPlease' 'Dinner, Fish'
#  'Appetizer, Snack, Dessert' 'Drink, Party' 'Breakfast, Taco'
#  'Entree, Pasta' 'Dinner, Lunch, Korean' 'Dinner, SoupPlease let'
#  'Breakfast, Brunch, Dinner,' 'Appetizer, Asian, Brunch, D'
#  'Dinner, Entree, Italian' 'Dinner, KoreanPlease let me'
#  'Appetizer, Dinner, Entrée' 'Dinner, SnackPlease let'
#  'Dessert, GreekPlease let' 'Dinner, FishPlease let me'
#  'Entree, AsianPlease let me' 'Appetizer, Sushi' 'Snack, Breakfast'
#  'Breakfast, Appetizer' 'Dinner, Salad, Entrée' 'Appetizer, Cocktail'
#  'Dessert, Brunch, Dinner' 'Dessert, Party Food' 'Beverage, Tea'
#  'Appetizer, Side dish' 'Lunch, Dinner, Soup' 'Lunch, DinnerPlease let'
#  'Japanese, Lunch, Dinner' 'Dinner, High Tea, Entrée'
#  'Dinner, PicnicPlease let' 'Breakfast, FrenchPlease let' 'Brunch, Snack'
#  'Pasta, Salad' 'Lunch, Snack, High Tea' 'Drink, Brunch, Picnic'
#  'Drinks, Brunch, Dessert' 'Dinner, Picnic, Entree'
#  'Breakfast, Coffee Break' 'Dinner, Appetizer, Lunch'
#  'Salad, Appetizer, Dessert' 'Dessert, Appetizer, Lunch'
#  'Breakfast, Dinner, Entree' 'Breakfast, VietnamesePlease'
#  'Dessert, Wine pairing' 'Dressing, Lunch, Salad' 'Dinner, Bread' 'Brunch'
#  'Dinner, Sandwich' 'Breakfast, Lunch, Tapas' 'Dinner, Picnic, Soup'
#  'Entree, Seafood' 'Entree, Pizza' 'Cocktail, Dinner'
#  'Lunch, SaladPlease let' 'Japanese, Dinner, Entree'
#  'Dinner, Breakfast, Lunch' 'Breakfast, Middle Eastern' 'Dinner, Pasta'
#  'Dinner, Picnic, Snack' 'Snack, Lunch' 'Dessert, Breakfast, Lunch'
#  'Brunch, Appetizer, High Tea' 'Picnic, Snack' 'Snack, Salad'
#  'Dinner, Brunch, Side dish' 'Entree, KoreanPlease let me'
#  'Salad, Appetizer, Dinner' 'Dinner, Entree, Soup'
#  'Drinks, Party, High Tea' 'Dinner, Holiday, Appetizer'
#  'Soup, Appetizer, Snack' 'Dessert, Appetizer, Salad'
#  'Dessert, Middle Eastern' 'Dinner, Wine' 'Dinner, Lunch, Brunch'
#  'Dessert, LunchPlease' 'Appetizer, Middle EasternPlease'
#  'Drinks, High Tea, Picnic' 'Dinner, Holiday, Main Course' 'Appetizer'
#  'Drinks, Appetizer, Dessert' 'Dinner, Appetizer, Soup,'
#  'Entree, JapanesePlease let me' 'High Tea, Brunch, Dessert'
#  'Dinner, Salad, Entree' 'Drink, High Tea, Dessert'
#  'Breakfast, Dinner, Lunch' 'Salad, Brunch' 'Brunch, Appetizer, Dessert'
#  'Dinner, Sushi' 'Dessert, PartyPlease let' 'Beverage, Herbal'
#  'Drinks, Snack' 'Dinner, Appetizer, Holiday' 'Dinner, Entree, Quick Meal'
#  'Dessert, Christmas' 'Appetizer, High Tea, Dinner'
#  'Drinks, Brunch, Appetizer' 'Dressing, Appetizer'
#  'Entree, Appetizer, Salad' 'Entree, Salad' 'Dinner, Slovakian'
#  'Dinner, Lunch, Vegetarian' 'Dessert, Wine'
#  'Appetizer, Dinner, Side dish' 'Dessert, Coffee' 'High Tea, Lunch, Snack'
#  'Entree, Appetizer, Dessert' 'Dessert, Pie' 'Dinner'
#  'Appetizer, Dessert, High Te' 'Dinner, Southern'
#  'Dessert, FilipinoPlease' 'Dinner, Middle Eastern'
#  'Dinner, Appetizer, Asian' 'Dinner, Appetizer, Drink' 'Snack'
#  'Dressing, Snack' 'Dinner, High Tea, Entree' 'Dinner, Appetizer, Greek'
#  'Dinner, Soup, Dessert' 'Dessert, Lunch, Picnic' 'Drink, Golf'
#  'Breakfast, Brunch, Entrée' 'Dessert, Holiday Meals' 'Picnic, Dessert'
#  'Entrée, Dessert' 'Dessert, Vegetarian' 'Dinner, Pizza' 'Entree, Drinks'
#  'Appetizer, Lunch, Salad' 'Dinner, Entree, Asian' 'Entree, Asian, Dinner'
#  'Dessert, Entree' 'Soup, Lunch, Dessert' 'Appetizer, Party'
#  'Snack, High Tea, Picnic' 'Breakfast, Brunch, Picnic'
#  'Dessert, Brunch, Picnic' 'Mexican, Lunch, Dinner' 'Dessert, Party'
#  'Dessert, High Tea, Dinner' 'Dinner, Side dish, High Tea'
#  'Drink, Brunch, Dessert' 'Dinner, Soup, Entrée'
#  'Dinner, Appetizer, Middle Eastern' 'Dinner, Salad, Soup'
#  'Breakfast, Dessert, Pastry' 'Dinner, Entree, Appetizer'
#  'Dessert, Appetizer, Soup' 'Dinner, High Tea, Dessert' 'Appetizer, Tea'
#  'Dinner, Brunch, Entrée' 'Breakfast, Brunch, Tea'
#  'Breakfast, Brunch, Lunch,' 'Entree, GreekPlease let me'
#  'Dinner, Entree, Brunch' 'Salad, Brunch, Dessert' 'Dessert, SoupPlease'
#  'Entree, Sushi' 'Picnic, Salad' 'Dessert, High Tea, Brunch'
#  'Breakfast, Picnic' 'Dessert, DinnerPlease'
#  'Appetizer, Breakfast, Dessert' 'Lunch, Dinner, Picnic'
#  'Baked Goods, Snack' 'Bread, Breakfast, Brunch, D'
#  'Dinner, Brunch, Entree' 'Entree, Middle Eastern'
#  'Dinner, RoastPlease let' 'Dinner, Holiday, Salad'
#  'Lunch, High Tea, Appetizer' 'Breakfast, Brunch, Juice'
#  'Appetizer, VietnamesePlease' 'Appetizer, Picnic, Dessert'
#  'Dinner, ItalianPlease provide the' 'Dessert, Breakfast, Appetizer'
#  'Dinner, FishPlease provide the' 'High Tea, Appetizer'
#  'Appetizer, Drinks, High Tea' 'Dinner, Latin AmericanPlease let'
#  'Appetizer, Dinner, Drink' 'Dessert, Brazilian'
#  'Appetizer, PartyPlease let' 'Dessert, Jam' 'Dessert, High Tea, Lunch'
#  'Dinner, EntréePlease' 'Drinks, Picnic' 'Dinner, Street Food'
#  'Dessert, JapanesePlease let' 'Dessert, Lunch, Appetizer'
#  'Dinner, Vegetarian' 'Appetizer, SoupPlease' 'Dinner, Entrée, High Tea'
#  'Dinner, Family Meal' 'Dinner, Kids Meal' 'Entree, Dim Sum'
#  'Brunch, Appetizer, Dinner' 'Dinner, Movie Night'
#  'Appetizer, Drinks, Dessert' 'Dinner, Wine pairing' 'Dinner, Main Course'
#  'Entree, Vegetarian' 'Breakfast, BrunchPlease' 'Dinner, Asian'
#  'Dessert, GreekPlease provide' 'Bread, Dinner, Appetizer'
#  'Dinner, Picnic, BBQ' 'Appetizer, Drinks, Party'
#  'Dinner, Drinks, High Tea' 'Bread, Dinner, Entrée'
#  'Entree, ItalianPlease let me' 'Drinks' 'Lunch, Picnic, Dessert'
#  'Dinner, Supper' 'Dinner, Soup, Salad' 'Dinner, Side dish, Dessert'
#  'Breakfast, Tacos' 'Drinks, High Tea, Dessert' 'Lunch, Dinner, Entree'
#  'Dessert, Side dish' 'Dinner, Fish, Appetizer' 'Brunch, Salad'
#  'Breakfast, Dessert, Snack' 'Dessert, Supper' 'Bread, Dessert'
#  'Appetizer, Drink, Dessert' 'Dinner, BrazilianPlease provide'
#  'Dinner, Holiday, Picnic' 'Lunch, SnackPlease provide']

# %% [markdown]
# Below is a summary of the unique values and their counts for each categorical column:
#
# ### Summary of Categorical Columns
#
# 1. **`wine_type`**:
#    - Total unique types: **5,871**
#    - Most common combinations:
#      - `[Chardonnay, Sauvignon Blanc, Riesling, Pinot Grigio]` appears **6,708** times.
#      - `[Chardonnay, Pinot Grigio, Sauvignon Blanc, Riesling]` appears **4,051** times.
#    - There’s a wide variety of wine combinations, with some very specific or unique entries appearing only once.
#
# 2. **`allergy_type`**:
#    - Total unique types: **31,229**
#    - Most common types:
#      - `[Alcohol]` appears **555** times.
#      - `[Dairy, Sugar]` appears **436** times.
#    - This high variety indicates that the dataset includes many specific combinations of allergens, possibly to cover a range of dietary restrictions and food sensitivities.
#
# 3. **`diet_type`**:
#    - Total unique types: **9,300**
#    - Most common types:
#      - `[(Paleo,80),(Ketogenic,70),(Atkins,60),(SouthBeach,50)]` appears **3,893** times.
#      - `[(Vegetarian,80),(Dairy-Free,70),(Lactovegetarians,60),(OvoVegetarian,50),(Paleo,40)]` appears **3,637** times.
#    - The dataset covers a wide range of diet types, often combining several diets in one entry, which reflects complex dietary needs.
#
# 4. **`holiday`**:
#    - Total unique types: **271**
#    - Most common holidays:
#      - `Thanksgiving` appears **30,103** times.
#      - `Easter` appears **12,535** times.
#      - `New Year’s Eve` appears **9,417** times.
#    - The dataset is heavily centered around traditional American holidays, with a few unique or rare holidays.
#
# 5. **`cuisine_type`**:
#    - Total unique types: **1,385**
#    - Most common cuisines:
#      - `American` appears **19,038** times.
#      - `Italian` appears **6,659** times.
#      - `American, Italian` appears **5,802** times.
#    - The dataset is diverse in terms of cuisine, with combinations of multiple cuisines being common.
#
# 6. **`meal_type`**:
#    - Total unique types: **4,449**
#    - Most common meal types:
#      - `Dinner, Appetizer` appears **8,398** times.
#      - `Dinner, Entree` appears **7,542** times.
#      - `Dessert, Snack` appears **6,581** times.
#    - There are many meal-type combinations, with dinner, dessert, and snacks being the most frequently mentioned.
#
# ### Observations
# - The dataset exhibits significant variety within each categorical column, especially for `allergy_type` and `diet_type`, which likely reflects the need to address a wide array of dietary restrictions.
# - Certain categories, like `wine_type` and `meal_type`, have high counts for specific combinations, indicating common pairings (e.g., certain wine types paired together or typical meal courses).
# - **Thanksgiving** is the most popular holiday in the dataset by a large margin, and **American cuisine** is the most common, which may suggest a bias towards American food culture in this dataset.
#
# This diversity in categorical data can provide interesting insights and challenges when analyzing food-related trends, such as the popularity of specific cuisines during holidays or the commonality of certain dietary restrictions.

# %% [markdown]
# ### 4. Multi-Label Analysis

# %%
# Some columns, liek allergy_type, diet_type, and wine_type, contains list of multiple items.
# Multiple label-columns

# Define the multi-label columns you want to analyze
multi_label_columns = ['allergy_type', 'diet_type', 'wine_type']

# Loop through each column and perform analysis
for column in multi_label_columns:
    print(f"\nAnalysis for '{column}' column:")

    # Explode the column so each item in the list becomes a separate row
    exploded_df = train_df.copy()
    exploded_df[column] = exploded_df[column].str.strip('[]').str.replace("'", "").str.split(',')
    exploded_df = exploded_df.explode(column)

    # Clean up whitespace if necessary
    exploded_df[column] = exploded_df[column].str.strip()

    # Display the value counts for the exploded column
    print(exploded_df[column].value_counts().head(10))  # Display top 10 most common items
# Out:
# Analysis for 'allergy_type' column:
# allergy_type
# Milk      19787
# Nut       17233
# Dairy     16635
# Egg       14430
# Wheat     13055
# Fruit     12360
# Soy        9909
# Sugar      8496
# Gluten     8467
# Meat       7582
# Name: count, dtype: int64
#
# Analysis for 'diet_type' column:
# diet_type
# 70)                  73274
# 80)                  72163
# 60)                  71318
# (Paleo               64591
# 50)                  62555
# (Vegetarian          47584
# (Dairy-Free          43652
# 40)                  43181
# (Lactovegetarians    32906
# (OvoVegetarian       27658
# Name: count, dtype: int64
#
# Analysis for 'wine_type' column:
# wine_type
# Chardonnay            51387
# Sauvignon Blanc       43221
# Pinot Grigio          35952
# Riesling              33077
# Vermentino            12976
# Tempranillo           10223
# Moscato                7694
# Cabernet Sauvignon     6198
# Gewürztraminer         6092
# Zinfandel              5551
# Name: count, dtype: int64

# %% [markdown]
# Belwo is a summary of the exploded multi-label analysis for each of the columns.
#
# ### Summary of Multi-Label Analysis
#
# #### 1. **`allergy_type`**:
#    - The most common allergens identified in recipes are:
#      - **Milk** (19,787 occurrences)
#      - **Nut** (17,233 occurrences)
#      - **Dairy** (16,635 occurrences)
#      - **Egg** (14,430 occurrences)
#      - **Wheat** (13,055 occurrences)
#    - Other frequently listed allergens include **Fruit**, **Soy**, **Sugar**, **Gluten**, and **Meat**.
#    - This distribution highlights that many recipes are not compatible with common allergens, particularly dairy, nuts, and wheat, which are often problematic for those with food sensitivities.
#
# #### 2. **`diet_type`**:
#    - The values for `diet_type` have some irregular formatting, where counts include percentages (like `70)`, `80)`), which appear due to incomplete or unstructured data.
#    - **Popular Diet Types**:
#      - The diet type **Paleo** appears frequently (64,591 occurrences), followed by **Vegetarian** (47,584 occurrences) and **Dairy-Free** (43,652 occurrences).
#      - **Lactovegetarians** (32,906) and **OvoVegetarians** (27,658) are also common, indicating a mix of plant-based and specialized diets.
#    - It may be beneficial to clean this data by removing or restructuring the percentage values for more accurate analysis.
#
# #### 3. **`wine_type`**:
#    - The most commonly paired wine types with recipes are:
#      - **Chardonnay** (51,387 occurrences)
#      - **Sauvignon Blanc** (43,221 occurrences)
#      - **Pinot Grigio** (35,952 occurrences)
#      - **Riesling** (33,077 occurrences)
#    - Other popular wine types include **Vermentino**, **Tempranillo**, **Moscato**, **Cabernet Sauvignon**, **Gewürztraminer**, and **Zinfandel**.
#    - This suggests a preference for light and versatile white wines (like Chardonnay, Sauvignon Blanc, and Pinot Grigio) in recipe pairings.
#
# ### Observations
# - **Common Allergens**: Milk, nuts, dairy, and eggs are the most frequent allergens, underscoring their prevalence in many recipes and the importance of allergen labeling.
# - **Diet Types**: Paleo and various vegetarian or dairy-free diets are well-represented, though the `diet_type` column would benefit from data cleaning to remove artifacts like percentages.
# - **Wine Pairings**: White wines dominate the pairing choices, with Chardonnay being the top choice, followed by Sauvignon Blanc and Pinot Grigio.

# %% [markdown]
# ### 5. Numerical Analysis

# %%
# Statistics for numerical columns (if any)
# Identify numerical columns in the DataFrame
numerical_columns = train_df.select_dtypes(include=['number']).columns

# Check if there are any numerical columns
if len(numerical_columns) > 0:
    # Display descriptive statistics for numerical columns
    descriptive_stats = train_df[numerical_columns].describe().transpose()
    descriptive_stats['median'] = train_df[numerical_columns].median()

    print("Descriptive Statistics for Numerical Columns:")
    print(descriptive_stats)
else:
    print("No numerical columns found in the dataset.")
# Out:
# No numerical columns found in the dataset.

# %% [markdown]
# ### 6. Relationship Analysis

# %% [markdown]
# #### Diet vs. Allergies: Investigate if there are patterms or correlations between diet_type and allergy_type.
#
# We have used .explode() to treat each list item separately and then create a crosstab.

# %%
# Explode diet_type and allergy_type columns
diet_allergy_df = train_df.copy()
diet_allergy_df['diet_type'] = diet_allergy_df['diet_type'].str.strip('[]').str.replace("'", "").str.split(',')
diet_allergy_df['allergy_type'] = diet_allergy_df['allergy_type'].str.strip('[]').str.replace("'", "").str.split(',')
diet_allergy_df = diet_allergy_df.explode('diet_type').explode('allergy_type')

# Clean up any extra whitespace
diet_allergy_df['diet_type'] = diet_allergy_df['diet_type'].str.strip()
diet_allergy_df['allergy_type'] = diet_allergy_df['allergy_type'].str.strip()

# Create a crosstab to view the frequency of each diet and allergy combination
diet_allergy_crosstab = pd.crosstab(diet_allergy_df['diet_type'], diet_allergy_df['allergy_type'])

# Display the crosstab
print("Diet vs. Allergy Crosstab:")
print(diet_allergy_crosstab)
# Out:
# Diet vs. Allergy Crosstab:
# allergy_type                                           Acid  Acidic  Acidity  \
# diet_type
#                                                     0     0       0        0
# "driedshrimp"isnotdairy-free                        0     0       0        0
# (                                                   0     0       0        0
# ((Dairy-Free                                        0     0       0        0
# ((Vegetarian                                        0     0       0        0
# ...                                                ..   ...     ...      ...
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...  0     0       0        0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...  0     0       0        0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...  0     0       0        0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...  0     0       0        0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...  0     0       0        0
#
# allergy_type                                        Acorn squash  Adhesive  \
# diet_type
#                                                                0         0
# "driedshrimp"isnotdairy-free                                   0         0
# (                                                              0         0
# ((Dairy-Free                                                   0         0
# ((Vegetarian                                                   0         0
# ...                                                          ...       ...
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...             0         0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...             0         0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...             0         0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...             0         0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...             0         0
#
# allergy_type                                        Adobo  Agave  Aioli  \
# diet_type
#                                                         0      0      0
# "driedshrimp"isnotdairy-free                            0      0      0
# (                                                       0      0      0
# ((Dairy-Free                                            0      0      0
# ((Vegetarian                                            0      0      0
# ...                                                   ...    ...    ...
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...      0      0      0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...      0      0      0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...      0      0      0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...      0      0      0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...      0      0      0
#
# allergy_type                                        Alcohol  ...  \
# diet_type                                                    ...
#                                                           3  ...
# "driedshrimp"isnotdairy-free                              0  ...
# (                                                         0  ...
# ((Dairy-Free                                              0  ...
# ((Vegetarian                                              0  ...
# ...                                                     ...  ...
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...        1  ...
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...        0  ...
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...        0  ...
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...        0  ...
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...        0  ...
#
# allergy_type                                        which is a common allergen  \
# diet_type
#                                                                              0
# "driedshrimp"isnotdairy-free                                                 0
# (                                                                            0
# ((Dairy-Free                                                                 0
# ((Vegetarian                                                                 0
# ...                                                                        ...
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                           0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                           0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                           0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                           0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                           0
#
# allergy_type                                        which is not typically considered an allergen However  \
# diet_type
#                                                                                                     0
# "driedshrimp"isnotdairy-free                                                                        0
# (                                                                                                   0
# ((Dairy-Free                                                                                        0
# ((Vegetarian                                                                                        0
# ...                                                                                               ...
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
#
# allergy_type                                        which may pose a risk for individuals with egg allergies  \
# diet_type
#                                                                                                     0
# "driedshrimp"isnotdairy-free                                                                        0
# (                                                                                                   0
# ((Dairy-Free                                                                                        0
# ((Vegetarian                                                                                        0
# ...                                                                                               ...
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
#
# allergy_type                                        which may pose an issue for individuals who are allergic to eggs However  \
# diet_type
#                                                                                                     0
# "driedshrimp"isnotdairy-free                                                                        0
# (                                                                                                   0
# ((Dairy-Free                                                                                        0
# ((Vegetarian                                                                                        0
# ...                                                                                               ...
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
#
# allergy_type                                        while others are not  \
# diet_type
#                                                                        0
# "driedshrimp"isnotdairy-free                                           0
# (                                                                      0
# ((Dairy-Free                                                           0
# ((Vegetarian                                                           0
# ...                                                                  ...
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                     0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                     0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                     0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                     0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                     0
#
# allergy_type                                        you can substitute the egg yolks with 2 flax eggs (1 tablespoon ground flaxseed + 3 tablespoons water  \
# diet_type
#                                                                                                     0
# "driedshrimp"isnotdairy-free                                                                        0
# (                                                                                                   0
# ((Dairy-Free                                                                                        0
# ((Vegetarian                                                                                        0
# ...                                                                                               ...
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
#
# allergy_type                                        you can substitute with 1/4 teaspoon of flaxseed meal mixed with 2 tablespoons of water Let the mixture sit for 5 minutes before using in place of the egg yolk  \
# diet_type
#                                                                                                     0
# "driedshrimp"isnotdairy-free                                                                        0
# (                                                                                                   0
# ((Dairy-Free                                                                                        0
# ((Vegetarian                                                                                        0
# ...                                                                                               ...
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
#
# allergy_type                                        you can substitute with an additional 2 tablespoons of aioli or mayonnaise instead  \
# diet_type
#                                                                                                     0
# "driedshrimp"isnotdairy-free                                                                        0
# (                                                                                                   0
# ((Dairy-Free                                                                                        0
# ((Vegetarian                                                                                        0
# ...                                                                                               ...
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
#
# allergy_type                                        you can substitute with an equal amount of granulated sugar  \
# diet_type
#                                                                                                     0
# "driedshrimp"isnotdairy-free                                                                        0
# (                                                                                                   0
# ((Dairy-Free                                                                                        0
# ((Vegetarian                                                                                        0
# ...                                                                                               ...
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                                  0
#
# allergy_type                                        you should avoid consuming this drink
# diet_type
#                                                                                         0
# "driedshrimp"isnotdairy-free                                                            0
# (                                                                                       0
# ((Dairy-Free                                                                            0
# ((Vegetarian                                                                            0
# ...                                                                                   ...
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                      0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                      0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                      0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                      0
# zestedandjuiced\n2tbspoliveoil\n2tbspchoppedfre...                                      0
#
# [4562 rows x 1694 columns]

# %% [markdown]
# The output of the **Diet vs. Allergy** crosstab shows the frequency of each diet type alongside different allergens. Here’s a summary of what this large table indicates:
#
# ##### Summary of Diet vs. Allergy Crosstab
#
# 1. **Structure of the Crosstab**:
#    - The crosstab has **4,562 rows** (representing unique diet types) and **1,694 columns** (representing unique allergens).
#    - Each cell in the table represents the count of recipes associated with a specific combination of diet type and allergen.
#
# 2. **Issues with Data Quality**:
#    - There are many values in `diet_type` that appear to be artifacts or poorly structured entries, such as `"(Dairy-Free"`, `"(Vegetarian"`, and phrases like `"you can substitute with an equal amount of granulated sugar"`.
#    - These unstructured entries likely resulted from irregular formatting or embedded notes in the data. This is causing additional rows in the crosstab that may not represent true diet types.
#
# 3. **Insights from Valid Data**:
#    - Despite the unstructured entries, valid diet types (like `Dairy-Free`, `Vegetarian`, `Paleo`) and allergens (like `Milk`, `Nut`, `Wheat`, `Egg`) can still provide insights:
#      - **Common Allergens Across Diets**: Popular diet types like `Dairy-Free` and `Vegetarian` appear to co-occur with common allergens like **Milk**, **Nuts**, and **Wheat**, likely indicating the need for recipes that cater to these restrictions within these diets.
#      - **Patterns by Diet**: The crosstab seems to reveal patterns in which certain diet types are less compatible with specific allergens. For example, if `Dairy-Free` recipes commonly lack **Milk** but contain **Nuts**, this might suggest a trade-off in recipe ingredients to maintain dietary restrictions.

# %% [markdown]
# #### Holiday vs. Cuisine: Check if specific holidays are associated with certain cuisines.
#
# We can again use .explode() on cuisine_type if it contains multiple entries per recipe.

# %%
 # Explode the cuisine_type column
holiday_cuisine_df = train_df.copy()
holiday_cuisine_df['cuisine_type'] = holiday_cuisine_df['cuisine_type'].str.strip('[]').str.replace("'", "").str.split(',')
holiday_cuisine_df = holiday_cuisine_df.explode('cuisine_type')

# Clean up any extra whitespace
holiday_cuisine_df['cuisine_type'] = holiday_cuisine_df['cuisine_type'].str.strip()

# Create a crosstab for holiday and cuisine_type
holiday_cuisine_crosstab = pd.crosstab(holiday_cuisine_df['holiday'], holiday_cuisine_df['cuisine_type'])

# Display the crosstab
print("Holiday vs. Cuisine Crosstab:")
print(holiday_cuisine_crosstab)
# Out:
# Holiday vs. Cuisine Crosstab:
# cuisine_type                                 * African* Middle Eastern  \
# holiday
#  Cinco de Mayo                            0                          0
# 4th of July                               0                          0
# All Hallows Eve                           0                          0
# Anniversary                               0                          0
# Australia Day                             0                          0
# ...                                      ..                        ...
# Winter/Holiday Season                     0                          0
# Winter/New Year's Eve                     0                          0
# Winter/Spring Break                       0                          0
# WinterPlease answer with only one phrase  0                          0
# Winterrecipe title:                       0                          0
#
# cuisine_type                              * Eastern European  \
# holiday
#  Cinco de Mayo                                             0
# 4th of July                                                0
# All Hallows Eve                                            0
# Anniversary                                                0
# Australia Day                                              0
# ...                                                      ...
# Winter/Holiday Season                                      0
# Winter/New Year's Eve                                      0
# Winter/Spring Break                                        0
# WinterPlease answer with only one phrase                   0
# Winterrecipe title:                                        0
#
# cuisine_type                              * European* Middle Eastern  \
# holiday
#  Cinco de Mayo                                                     0
# 4th of July                                                        0
# All Hallows Eve                                                    0
# Anniversary                                                        0
# Australia Day                                                      0
# ...                                                              ...
# Winter/Holiday Season                                              0
# Winter/New Year's Eve                                              0
# Winter/Spring Break                                                0
# WinterPlease answer with only one phrase                           0
# Winterrecipe title:                                                0
#
# cuisine_type                              * Jewish* Eastern European  \
# holiday
#  Cinco de Mayo                                                     0
# 4th of July                                                        0
# All Hallows Eve                                                    0
# Anniversary                                                        0
# Australia Day                                                      0
# ...                                                              ...
# Winter/Holiday Season                                              0
# Winter/New Year's Eve                                              0
# Winter/Spring Break                                                0
# WinterPlease answer with only one phrase                           0
# Winterrecipe title:                                                0
#
# cuisine_type                              AfghanText: Lemon-  African  \
# holiday
#  Cinco de Mayo                                             0        0
# 4th of July                                                0        1
# All Hallows Eve                                            0        0
# Anniversary                                                0        0
# Australia Day                                              0        0
# ...                                                      ...      ...
# Winter/Holiday Season                                      0        0
# Winter/New Year's Eve                                      0        0
# Winter/Spring Break                                        0        0
# WinterPlease answer with only one phrase                   0        0
# Winterrecipe title:                                        0        0
#
# cuisine_type                              Alaskan  American  AmericanMexican  \
# holiday
#  Cinco de Mayo                                  0         1                0
# 4th of July                                     0      3408                0
# All Hallows Eve                                 0         0                0
# Anniversary                                     0         2                0
# Australia Day                                   0         0                0
# ...                                           ...       ...              ...
# Winter/Holiday Season                           0        62                0
# Winter/New Year's Eve                           0         4                0
# Winter/Spring Break                             0         1                0
# WinterPlease answer with only one phrase        0         4                0
# Winterrecipe title:                             0         5                0
#
# cuisine_type                              ...  West African  \
# holiday                                   ...
#  Cinco de Mayo                            ...             0
# 4th of July                               ...             0
# All Hallows Eve                           ...             0
# Anniversary                               ...             0
# Australia Day                             ...             0
# ...                                       ...           ...
# Winter/Holiday Season                     ...             0
# Winter/New Year's Eve                     ...             0
# Winter/Spring Break                       ...             0
# WinterPlease answer with only one phrase  ...             0
# Winterrecipe title:                       ...             0
#
# cuisine_type                              West AfricanNote: The term "West  \
# holiday
#  Cinco de Mayo                                                           0
# 4th of July                                                              0
# All Hallows Eve                                                          0
# Anniversary                                                              0
# Australia Day                                                            0
# ...                                                                    ...
# Winter/Holiday Season                                                    0
# Winter/New Year's Eve                                                    0
# Winter/Spring Break                                                      0
# WinterPlease answer with only one phrase                                 0
# Winterrecipe title:                                                      0
#
# cuisine_type                              Western  Whiskey  Yucatan  \
# holiday
#  Cinco de Mayo                                  0        0        0
# 4th of July                                     2        0        1
# All Hallows Eve                                 0        0        0
# Anniversary                                     0        0        0
# Australia Day                                   0        0        0
# ...                                           ...      ...      ...
# Winter/Holiday Season                           0        0        0
# Winter/New Year's Eve                           0        0        0
# Winter/Spring Break                             0        0        0
# WinterPlease answer with only one phrase        0        0        0
# Winterrecipe title:                             0        0        0
#
# cuisine_type                              Yucatecan  YucatecanText: Ch  \
# holiday
#  Cinco de Mayo                                    0                  0
# 4th of July                                       0                  0
# All Hallows Eve                                   0                  0
# Anniversary                                       0                  0
# Australia Day                                     0                  0
# ...                                             ...                ...
# Winter/Holiday Season                             0                  0
# Winter/New Year's Eve                             0                  0
# Winter/Spring Break                               0                  0
# WinterPlease answer with only one phrase          0                  0
# Winterrecipe title:                               0                  0
#
# cuisine_type                              YucatecanText: Sp  \
# holiday
#  Cinco de Mayo                                            0
# 4th of July                                               0
# All Hallows Eve                                           0
# Anniversary                                               0
# Australia Day                                             0
# ...                                                     ...
# Winter/Holiday Season                                     0
# Winter/New Year's Eve                                     0
# Winter/Spring Break                                       0
# WinterPlease answer with only one phrase                  0
# Winterrecipe title:                                       0
#
# cuisine_type                              cook the end of the end of the end of  \
# holiday
#  Cinco de Mayo                                                                0
# 4th of July                                                                   0
# All Hallows Eve                                                               0
# Anniversary                                                                   0
# Australia Day                                                                 0
# ...                                                                         ...
# Winter/Holiday Season                                                         0
# Winter/New Year's Eve                                                         0
# Winter/Spring Break                                                           0
# WinterPlease answer with only one phrase                                      0
# Winterrecipe title:                                                           0
#
# cuisine_type                              gdsgesgbsgygeg
# holiday
#  Cinco de Mayo                                         0
# 4th of July                                            0
# All Hallows Eve                                        0
# Anniversary                                            0
# Australia Day                                          0
# ...                                                  ...
# Winter/Holiday Season                                  0
# Winter/New Year's Eve                                  0
# Winter/Spring Break                                    0
# WinterPlease answer with only one phrase               0
# Winterrecipe title:                                    0
#
# [271 rows x 753 columns]

# %% [markdown]
# The **Holiday vs. Cuisine** crosstab reveals the frequency of specific cuisines associated with different holidays. Below is a summary of the main points:
#
# ##### Summary of Holiday vs. Cuisine Crosstab
#
# 1. **Structure of the Crosstab**:
#    - The crosstab contains **271 rows** (representing unique holidays) and **753 columns** (representing unique cuisines).
#    - Each cell represents the number of recipes associated with a specific holiday and cuisine pairing.
#
# 2. **Observations on Data Quality**:
#    - There are numerous irregular entries in the `cuisine_type` column, such as `"AfghanText: Lemon-"`, `"Winterrecipe title:"`, and `"gdsgesgbsgygeg"`. These likely result from unstructured data or incorrectly parsed text, which add unnecessary complexity to the analysis.
#    - Similar issues appear in `holiday` (e.g., `"WinterPlease answer with only one phrase"`), indicating that some holiday values may also need cleaning for meaningful insights.
#
# 3. **Key Insights (Ignoring Data Artifacts)**:
#    - **Most Popular Holidays**: Certain holidays, such as `4th of July`, have substantial counts across various American cuisines, indicating a strong association with American culinary traditions.
#    - **4th of July**: This holiday appears frequently with **American** cuisine, as well as combinations with Mexican (e.g., "AmericanMexican") and Western influences.
#    - **Thanksgiving**: While specific counts aren’t visible in this summary, Thanksgiving is traditionally associated with American cuisine, which might show up with high values in the original table.
#    - **Global Representation**: The crosstab also includes a broad range of cuisines from various regions (e.g., "Middle Eastern", "African", "Yucatecan"), suggesting some cultural diversity within holiday-themed recipes.
#
# 4. **Patterns by Cuisine Type**:
#    - **American Cuisine**: Strongly represented across a variety of holidays, especially **4th of July** and **Thanksgiving**, reinforcing its significance in American holiday traditions.
#    - **Niche Cuisines**: Less common cuisines (e.g., "West African" or "Yucatecan") have sparse representation across holidays, with few associations.
#    - **Cultural Holidays and Specific Cuisines**: Certain holidays, like **Cinco de Mayo**, traditionally associated with Mexican culture, appear in the table but with limited counts due to the sparse data structure.

# %% [markdown]
# #### Wine Paitings: Look into common wine types associated with specific recipes.

# %%
# Explode both wine_type and cuisine_type columns
wine_cuisine_df = train_df.copy()
wine_cuisine_df['wine_type'] = wine_cuisine_df['wine_type'].str.strip('[]').str.replace("'", "").str.split(',')
wine_cuisine_df['cuisine_type'] = wine_cuisine_df['cuisine_type'].str.strip('[]').str.replace("'", "").str.split(',')
wine_cuisine_df = wine_cuisine_df.explode('wine_type').explode('cuisine_type')

# Clean up any extra whitespace
wine_cuisine_df['wine_type'] = wine_cuisine_df['wine_type'].str.strip()
wine_cuisine_df['cuisine_type'] = wine_cuisine_df['cuisine_type'].str.strip()

# Create a crosstab to view the relationship between wine type and cuisine type
wine_cuisine_crosstab = pd.crosstab(wine_cuisine_df['wine_type'], wine_cuisine_df['cuisine_type'])

# Display the top 10 wine types with their associated cuisine counts
top_wines = wine_cuisine_crosstab.loc[wine_pairing_counts.head(10).index]
print("Top 10 Wine Types and Associated Cuisine Counts:")
print(top_wines)
# Out:
# Top 10 Wine Types and Associated Cuisine Counts:
# cuisine_type           * African* Middle Eastern  * Eastern European  \
# wine_type
# Chardonnay          2                          1                   0
# Sauvignon Blanc     2                          1                   1
# Pinot Grigio        1                          1                   1
# Riesling            1                          0                   1
# Vermentino          1                          1                   0
# Tempranillo         1                          0                   0
# Moscato             0                          0                   0
# Cabernet Sauvignon  0                          0                   0
# Gewürztraminer      1                          0                   0
# Zinfandel           0                          0                   0
#
# cuisine_type        * European* Middle Eastern  * Jewish* Eastern European  \
# wine_type
# Chardonnay                                   1                           1
# Sauvignon Blanc                              0                           1
# Pinot Grigio                                 0                           1
# Riesling                                     1                           1
# Vermentino                                   0                           0
# Tempranillo                                  0                           0
# Moscato                                      1                           0
# Cabernet Sauvignon                           0                           0
# Gewürztraminer                               1                           0
# Zinfandel                                    0                           0
#
# cuisine_type        AfghanText: Lemon-  African  Alaskan  American  \
# wine_type
# Chardonnay                           1       42        1     37171
# Sauvignon Blanc                      1       37        1     29764
# Pinot Grigio                         1       27        1     25445
# Riesling                             1       21        1     25309
# Vermentino                           0       17        0      6801
# Tempranillo                          0       33        0      6754
# Moscato                              0        4        0      6432
# Cabernet Sauvignon                   0       10        0      5316
# Gewürztraminer                       0        5        0      4067
# Zinfandel                            0        9        0      4950
#
# cuisine_type        AmericanMexican  ...  West African  \
# wine_type                            ...
# Chardonnay                        3  ...             9
# Sauvignon Blanc                   3  ...             9
# Pinot Grigio                      1  ...             6
# Riesling                          3  ...             1
# Vermentino                        0  ...             5
# Tempranillo                       0  ...             6
# Moscato                           0  ...             0
# Cabernet Sauvignon                0  ...             0
# Gewürztraminer                    2  ...             0
# Zinfandel                         0  ...             0
#
# cuisine_type        West AfricanNote: The term "West  Western  Whiskey  \
# wine_type
# Chardonnay                                         0        3        0
# Sauvignon Blanc                                    0        3        0
# Pinot Grigio                                       0        2        0
# Riesling                                           0        0        0
# Vermentino                                         0        1        0
# Tempranillo                                        1        1        0
# Moscato                                            0        0        0
# Cabernet Sauvignon                                 0        1        0
# Gewürztraminer                                     0        0        0
# Zinfandel                                          0        2        0
#
# cuisine_type        Yucatan  Yucatecan  YucatecanText: Ch  YucatecanText: Sp  \
# wine_type
# Chardonnay                1          2                  0                  0
# Sauvignon Blanc           1          2                  0                  0
# Pinot Grigio              1          0                  1                  0
# Riesling                  0          0                  0                  0
# Vermentino                1          2                  0                  0
# Tempranillo               1          3                  1                  1
# Moscato                   0          0                  0                  0
# Cabernet Sauvignon        0          0                  0                  0
# Gewürztraminer            0          0                  0                  0
# Zinfandel                 1          2                  0                  1
#
# cuisine_type        cook the end of the end of the end of  gdsgesgbsgygeg
# wine_type
# Chardonnay                                              1               1
# Sauvignon Blanc                                         1               1
# Pinot Grigio                                            0               0
# Riesling                                                1               1
# Vermentino                                              0               0
# Tempranillo                                             0               0
# Moscato                                                 0               0
# Cabernet Sauvignon                                      0               0
# Gewürztraminer                                          1               1
# Zinfandel                                               0               0
#
# [10 rows x 753 columns]

# %% [markdown]
# ##### Summary of top 10 wines and associated cusine counts.
#
# Below is a summary of the **Top 10 Wine Types and Associated Cuisine Counts** crosstab outcome.
#
# 1. **Most Common Wine Pairings with American Cuisine**:
#    - **Chardonnay**, **Sauvignon Blanc**, **Pinot Grigio**, and **Riesling** are heavily associated with **American cuisine**. For example:
#      - **Chardonnay**: 37,171 associations with American cuisine.
#      - **Sauvignon Blanc**: 29,764 associations with American cuisine.
#      - **Pinot Grigio**: 25,445 associations with American cuisine.
#      - This suggests that American dishes commonly recommend these lighter, versatile wines.
#
# 2. **Cuisines with Lower Representation**:
#    - Cuisines like **African**, **West African**, **Middle Eastern**, and **Yucatecan** have much lower counts across all wine types. For example:
#      - **Chardonnay** has only 42 associations with **African** cuisine and 9 with **West African**.
#      - This could indicate that these cuisines are either less represented in the dataset or are not traditionally associated with these wine pairings.
#
# 3. **Irregular and Miscellaneous Entries**:
#    - Several entries in `cuisine_type` seem to be unstructured or contain extraneous information, such as:
#      - `"West AfricanNote: The term "West"`
#      - `"gdsgesgbsgygeg"`
#      - `"cook the end of the end of the end of"`
#    - These appear to be data artifacts or unstructured text, which may result from parsing errors or extraneous notes in the original data.
#
# 4. **Insights on Specific Wine Types**:
#    - **Tempranillo** and **Zinfandel** are associated with fewer cuisines, indicating they may be recommended for more specific dishes or cultural contexts.
#    - **Moscato** and **Gewürztraminer** have relatively low counts across the board, with a slight presence in **American** and **Western** cuisines. Moscato is often associated with desserts or sweeter dishes, which may be less frequently represented in general cuisine categories.
#
# 5. **Common Combinations**:
#    - **Chardonnay and American cuisine** is the most frequent pairing, followed by **Sauvignon Blanc with American cuisine**.
#    - Some unique pairings include **Tempranillo with Western** and **Riesling with European cuisines**.

# %% [markdown]
# ### 7. Alternative ingredients
#
# We performed text mining to identify the mose common ingredient substitutions.
#
# Explanation
#
# Function to Extract Alternatives: The extract_alternatives function uses regular expressions to identify the primary ingredient and its alternatives from each line in the ingredients_alternatives text.
#
# Flatten List of Alternatives: We apply the function to each row in ingredients_alternatives and flatten the results into a single list of ingredient pairs (primary, alternative).
#
# Counting Frequencies:
# alternative_counter counts how often each ingredient appears as a substitute, giving insight into popular substitutions.
# primary_counter counts the primary ingredients that are most often substituted.

# %%
import re
from collections import Counter

# Step 1: Preprocess and extract ingredient alternatives
def extract_alternatives(text):
    # Split each substitution by a newline and then use regex to find primary and alternative ingredients
    alternatives = []
    lines = text.split('\n')
    for line in lines:
        match = re.match(r'(\w+):\s*(.+)', line)  # Match 'Ingredient: alternatives'
        if match:
            primary = match.group(1).strip()
            substitutes = [alt.strip() for alt in match.group(2).split(',')]
            for substitute in substitutes:
                alternatives.append((primary, substitute))
    return alternatives

# Step 2: Apply the function to extract all alternatives
all_alternatives = []
for text in train_df['ingredients_alternatives'].dropna():
    all_alternatives.extend(extract_alternatives(text))

# Step 3: Count the frequency of each alternative
alternative_counter = Counter([alt[1] for alt in all_alternatives])

# Display the most common alternative ingredients
print("Most Common Alternative Ingredients:")
print(alternative_counter.most_common(10))

# Step 4 (Optional): Count the frequency of primary ingredient substitutions
primary_counter = Counter([alt[0] for alt in all_alternatives])
print("\nMost Common Primary Ingredients for Substitution:")
print(primary_counter.most_common(10))
# Out:
# Most Common Alternative Ingredients:
# [('shallots', 30720), ('scallions', 22876), ('maple syrup', 17123), ('green onions', 16347), ('ghee', 15030), ('kosher salt', 15008), ('coconut oil', 13228), ('whole wheat flour', 12891), ('basil', 12626), ('sea salt', 11713)]
#
# Most Common Primary Ingredients for Substitution:
# [('Garlic', 47018), ('Butter', 44147), ('Sugar', 40982), ('Salt', 38712), ('Flour', 36744), ('Onion', 30425), ('Eggs', 26258), ('Milk', 18087), ('Water', 15957), ('Parsley', 15460)]

# %% [markdown]
# ##### Summary of of the top 10 most common **alternative ingredients** and **primary ingredients** for substitution based on your analysis.
#
# 1. **Top 10 Most Frequent Alternative Ingredients**:
#    - **Shallots**: 30,720 occurrences
#    - **Scallions**: 22,876 occurrences
#    - **Maple Syrup**: 17,123 occurrences
#    - **Green Onions**: 16,347 occurrences
#    - **Ghee**: 15,030 occurrences
#    - **Kosher Salt**: 15,008 occurrences
#    - **Coconut Oil**: 13,228 occurrences
#    - **Whole Wheat Flour**: 12,891 occurrences
#    - **Basil**: 12,626 occurrences
#    - **Sea Salt**: 11,713 occurrences
#
# 2. **Insights**:
#    - **Frequent Substitutes for Common Ingredients**: Many of these alternatives (e.g., **shallots** for onions, **ghee** for butter, **maple syrup** for sweeteners) are often healthier or specialized substitutions.
#    - **Healthy Alternatives**: Ingredients like **coconut oil**, **whole wheat flour**, and **sea salt** suggest that many substitutions are aimed at health-conscious choices, with options that offer dietary benefits.
#    - **Interchangeable Ingredients**: Ingredients like **shallots** and **scallions** (or **green onions**) are closely related and frequently used as direct substitutes.
#
# ### Summary of Most Common Primary Ingredients for Substitution
# 1. **Top 10 Most Frequent Primary Ingredients**:
#    - **Garlic**: 47,018 occurrences
#    - **Butter**: 44,147 occurrences
#    - **Sugar**: 40,982 occurrences
#    - **Salt**: 38,712 occurrences
#    - **Flour**: 36,744 occurrences
#    - **Onion**: 30,425 occurrences
#    - **Eggs**: 26,258 occurrences
#    - **Milk**: 18,087 occurrences
#    - **Water**: 15,957 occurrences
#    - **Parsley**: 15,460 occurrences
#
# 2. **Insights**:
#    - **Common Cooking Staples**: The primary ingredients for substitution are largely staples in cooking and baking, such as **butter**, **sugar**, **salt**, **flour**, **eggs**, and **milk**.
#    - **Flavor and Dietary Adjustments**: Ingredients like **garlic** and **onion** are essential in flavor profiles, while **butter** and **milk** substitutions often cater to dairy-free or vegan alternatives.
#    - **Nutritional Preferences**: The prevalence of substitutions for **sugar**, **flour**, and **butter** indicates a trend towards finding healthier or allergen-free options in recipes.
#
# ### Overall Insights
# This analysis suggests a pattern where common ingredients in cooking (like butter, salt, and garlic) are often substituted with alternatives that meet dietary restrictions (e.g., dairy-free, low-sodium) or enhance healthfulness (e.g., using whole wheat flour or coconut oil). It reflects a growing demand for ingredient flexibility in recipes, likely driven by dietary needs and health trends.
