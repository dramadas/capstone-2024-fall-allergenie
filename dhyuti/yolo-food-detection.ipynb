# %% [markdown]
# ## Yolov8 Food Detection

# %%
import torch

# %%
from ultralytics import YOLO

# %% [markdown]
# ### First attempt: Yolo Object detection model (trained on COCO dataset)

# %%
model1 = YOLO("yolov8n.pt")

# %% [markdown]
# Using the base model (no fine-tuning), perform inference to assess if image contains food

# %%
# Perform object detection on an image
results = model1("carrot.jpg")
results[0].show()
# Out:
# image 1/1 /home/dramadas/Desktop/carrot.jpg: 640x640 4 carrots, 102.7ms
# Speed: 6.3ms preprocess, 102.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=1280x1280>

# %%
# Perform object detection on an image
results = model("tomato.jpg")
results[0].show()
# Out:
# image 1/1 /home/dramadas/Desktop/tomato.jpg: 480x640 1 apple, 2 oranges, 106.1ms
# Speed: 11.4ms preprocess, 106.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=900x675>

# %% [markdown]
# Try the same on AI generated image from our diffusion model:

# %%
# Perform object detection on an AI image
results = model("rag_cake.JPG")
results[0].show()
# Out:
# image 1/1 /home/dramadas/Desktop/rag_cake.JPG: 640x640 1 cake, 221.4ms
# Speed: 48.3ms preprocess, 221.4ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=573x571>

# %%
# Perform object detection on an image
results = model("rag_thai.JPG")
results[0].show()
# Out:
# image 1/1 /home/dramadas/Desktop/rag_thai.JPG: 640x640 1 bowl, 1 orange, 161.0ms
# Speed: 9.5ms preprocess, 161.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=567x572>

# %%
# Perform object detection on an image
results = model("rag_dessert.JPG")
results[0].show()
# Out:
# image 1/1 /home/dramadas/Desktop/rag_dessert.JPG: 640x640 1 donut, 1 cake, 156.4ms
# Speed: 9.9ms preprocess, 156.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=569x572>

# %% [markdown]
# ### Second Attempt: YOLO classification model (Trained on ImageNet)

# %%
model2 = YOLO("yolov8n-cls.pt")

# %%
results = model2("carrot.jpg")
# Out:
# image 1/1 /home/dramadas/Desktop/carrot.jpg: 224x224 hotdog 0.44, ice_lolly 0.15, studio_couch 0.11, French_loaf 0.04, wallet 0.02, 17.3ms
# Speed: 13.3ms preprocess, 17.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)

# %%
results = model2("tomato.jpg")
# Out:
# image 1/1 /home/dramadas/Desktop/tomato.jpg: 224x224 hip 0.92, bell_pepper 0.07, pomegranate 0.00, orange 0.00, ladybug 0.00, 23.7ms
# Speed: 12.7ms preprocess, 23.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)

# %%
results = model2("rag_cake.JPG")
# Out:
# image 1/1 /home/dramadas/Desktop/rag_cake.JPG: 224x224 trifle 0.76, strawberry 0.06, ice_cream 0.06, paper_towel 0.04, plate 0.01, 35.0ms
# Speed: 22.4ms preprocess, 35.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)

# %%
results = model2("rag_thai.JPG")
# Out:
# image 1/1 /home/dramadas/Desktop/rag_thai.JPG: 224x224 hot_pot 0.54, consomme 0.26, soup_bowl 0.16, caldron 0.01, wok 0.01, 21.1ms
# Speed: 7.3ms preprocess, 21.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)

# %%
results = model2("rag_dessert.JPG")
# Out:
# image 1/1 /home/dramadas/Desktop/rag_dessert.JPG: 224x224 acorn 0.59, screw 0.31, buckeye 0.02, thunder_snake 0.01, garter_snake 0.01, 15.3ms
# Speed: 5.6ms preprocess, 15.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)

# %% [markdown]
# ### Conclusion

# %% [markdown]
# To use Yolo base model as a food/not-food classifier, it will need to be fine tuned with a labeled dataset of food/not-food.
